# %%
from pso import particle_swarm_clustering
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\KARAN\Desktop\BBS Sir Proj\wine-clustering.csv',encoding='unicode_escape')
df
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6        127           2.80
# 1      13.20        1.78  2.14          11.2        100           2.65
# 2      13.16        2.36  2.67          18.6        101           2.80
# 3      14.37        1.95  2.50          16.8        113           3.85
# 4      13.24        2.59  2.87          21.0        118           2.80
# ..       ...         ...   ...           ...        ...            ...
# 173    13.71        5.65  2.45          20.5         95           1.68
# 174    13.40        3.91  2.48          23.0        102           1.80
# 175    13.27        4.28  2.26          20.0        120           1.59
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# ...

# %%
X=df.values
num_clusters = 3
num_particles = 10
max_iterations = 100
min_fitness = 1e-6
max_kmeans_iterations = 100
min_centroid_change = 1e-4
w, c1, c2 = 0.72, 1.49, 1.49

best_position, best_labels = particle_swarm_clustering(
    X, num_clusters, num_particles, max_iterations, min_fitness, max_kmeans_iterations, min_centroid_change,w,c1,c2
)
from sklearn.metrics import silhouette_score
silhouette_avg = silhouette_score(X, best_labels)
print("Silhouette Score:", silhouette_avg)
from sklearn.metrics import davies_bouldin_score
db_index = davies_bouldin_score(X, best_labels)
print("Davies-Bouldin Index:", db_index)
from sklearn.metrics import calinski_harabasz_score
ch_index = calinski_harabasz_score(X, best_labels)
print("Calinski-Harabasz Index:", ch_index)
# Out:
# Silhouette Score: 0.5660444291446176
# Davies-Bouldin Index: 0.5375596258335649
# Calinski-Harabasz Index: 559.121695452613

# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\KARAN\Desktop\BBS Sir Proj\iris-clustering.csv',encoding='unicode_escape')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 142           6.7          3.0           5.2          2.3
# 143           6.3          2.5           5.0          1.9
# 144           6.5          3.0           5.2          2.0
# 145           6.2          3.4           5.4          2.3
# 146           5.9          3.0           5.1          1.8
#
# [147 rows x 4 columns]

# %%
X=df.values
num_clusters = 3
num_particles = 10
max_iterations = 100
min_fitness = 1e-6
max_kmeans_iterations = 100
min_centroid_change = 1e-4
w, c1, c2 = 0.72, 1.49, 1.49

best_position, best_labels = particle_swarm_clustering(
    X, num_clusters, num_particles, max_iterations, min_fitness, max_kmeans_iterations, min_centroid_change,w,c1,c2
)
from sklearn.metrics import silhouette_score
silhouette_avg = silhouette_score(X, best_labels)
print("Silhouette Score:", silhouette_avg)
from sklearn.metrics import davies_bouldin_score
db_index = davies_bouldin_score(X, best_labels)
print("Davies-Bouldin Index:", db_index)
from sklearn.metrics import calinski_harabasz_score
ch_index = calinski_harabasz_score(X, best_labels)
print("Calinski-Harabasz Index:", ch_index)
# Out:
# Silhouette Score: 0.5493074238267263
# Davies-Bouldin Index: 0.6630766204621272
# Calinski-Harabasz Index: 541.4456169295247

# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\KARAN\Desktop\BBS Sir Proj\haberman-clustering.csv',encoding='unicode_escape')
df
# Out:
#      Age  Op_year  axil_nodes
# 0     30       62           3
# 1     30       65           0
# 2     31       59           2
# 3     31       65           4
# 4     33       58          10
# ..   ...      ...         ...
# 277   75       62           1
# 278   76       67           0
# 279   77       65           3
# 280   78       65           1
# 281   83       58           2
#
# [282 rows x 3 columns]

# %%
X=df.values
num_clusters = 2
num_particles = 10
max_iterations = 100
min_fitness = 1e-6
max_kmeans_iterations = 100
min_centroid_change = 1e-4
w, c1, c2 = 0.72, 1.49, 1.49

best_position, best_labels = particle_swarm_clustering(
    X, num_clusters, num_particles, max_iterations, min_fitness, max_kmeans_iterations, min_centroid_change,w,c1,c2
)
from sklearn.metrics import silhouette_score
silhouette_avg = silhouette_score(X, best_labels)
print("Silhouette Score:", silhouette_avg)
from sklearn.metrics import davies_bouldin_score
db_index = davies_bouldin_score(X, best_labels)
print("Davies-Bouldin Index:", db_index)
from sklearn.metrics import calinski_harabasz_score
ch_index = calinski_harabasz_score(X, best_labels)
print("Calinski-Harabasz Index:", ch_index)
# Out:
# Silhouette Score: 0.35862218575102467
# Davies-Bouldin Index: 1.3016927229112147
# Calinski-Harabasz Index: 74.6233841185008

# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\KARAN\Desktop\BBS Sir Proj\glass-clustering.csv',encoding='unicode_escape')
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...
# 208  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 209  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 210  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 211  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 212  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
# [213 rows x 9 columns]

# %%
X=df.values
num_clusters = 6
num_particles = 10
max_iterations = 100
min_fitness = 1e-6
max_kmeans_iterations = 100
min_centroid_change = 1e-4
w, c1, c2 = 0.72, 1.49, 1.49

best_position, best_labels = particle_swarm_clustering(
    X, num_clusters, num_particles, max_iterations, min_fitness, max_kmeans_iterations, min_centroid_change,w,c1,c2
)
from sklearn.metrics import silhouette_score
silhouette_avg = silhouette_score(X, best_labels)
print("Silhouette Score:", silhouette_avg)
from sklearn.metrics import davies_bouldin_score
db_index = davies_bouldin_score(X, best_labels)
print("Davies-Bouldin Index:", db_index)
from sklearn.metrics import calinski_harabasz_score
ch_index = calinski_harabasz_score(X, best_labels)
print("Calinski-Harabasz Index:", ch_index)
# Out:
# Silhouette Score: 0.4286573660040845
# Davies-Bouldin Index: 0.8899056741316537
# Calinski-Harabasz Index: 122.43483783817545

# %%
df=pd.read_csv(r'C:\Users\KARAN\Desktop\BBS Sir Proj\breast-cancer-clustering.csv',encoding='unicode_escape')
df
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
X=df.values
num_clusters = 2
num_particles = 10
max_iterations = 100
min_fitness = 1e-6
max_kmeans_iterations = 100
min_centroid_change = 1e-4
w, c1, c2 = 0.72, 1.49, 1.49

best_position, best_labels = particle_swarm_clustering(
    X, num_clusters, num_particles, max_iterations, min_fitness, max_kmeans_iterations, min_centroid_change,w,c1,c2
)
from sklearn.metrics import silhouette_score
silhouette_avg = silhouette_score(X, best_labels)
print("Silhouette Score:", silhouette_avg)
from sklearn.metrics import davies_bouldin_score
db_index = davies_bouldin_score(X, best_labels)
print("Davies-Bouldin Index:", db_index)
from sklearn.metrics import calinski_harabasz_score
ch_index = calinski_harabasz_score(X, best_labels)
print("Calinski-Harabasz Index:", ch_index)
# Out:
# Silhouette Score: 0.6921130838412453
# Davies-Bouldin Index: 0.5138529587569871
# Calinski-Harabasz Index: 1278.5708744446108
