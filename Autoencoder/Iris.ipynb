# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\KARAN\Desktop\BBS Sir Proj\iris-clustering.csv',encoding='unicode_escape')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 142           6.7          3.0           5.2          2.3
# 143           6.3          2.5           5.0          1.9
# 144           6.5          3.0           5.2          2.0
# 145           6.2          3.4           5.4          2.3
# 146           5.9          3.0           5.1          1.8
#
# [147 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
## we will do the splitting using a random state to ensure same splitting every time
X_train, X_test = train_test_split(df.values,test_size = .3,random_state = 13)

# %%
X_train
# Out:
# array([[5.1, 3.8, 1.9, 0.4],
#        [6.3, 2.5, 4.9, 1.5],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.6, 2.7, 4.2, 1.3],
#        [6.7, 3.3, 5.7, 2.1],
#        [4.9, 3.1, 1.5, 0.1],
#        [4.9, 2.4, 3.3, 1. ],
#        [4.7, 3.2, 1.6, 0.2],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.8, 2.7, 3.9, 1.2],
#        [5.9, 3. , 5.1, 1.8],
#        [4.6, 3.1, 1.5, 0.2],
#        [4.8, 3. , 1.4, 0.3],
#        [7.1, 3. , 5.9, 2.1],
#        [6.6, 2.9, 4.6, 1.3],
#        [6.3, 2.9, 5.6, 1.8],
#        [5.8, 2.8, 5.1, 2.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [6.1, 3. , 4.9, 1.8],
#        [6. , 2.2, 4. , 1. ],
#        [6.7, 3.3, 5.7, 2.5],
#        [7. , 3.2, 4.7, 1.4],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.2, 2.7, 3.9, 1.4],
#        [5.6, 2.5, 3.9, 1.1],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [5.7, 2.8, 4.5, 1.3],
#        [5.7, 2.5, 5. , 2. ],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.5, 3. , 5.5, 1.8],
#        [5. , 3.4, 1.6, 0.4],
#        [6.5, 3. , 5.2, 2. ],
#        [5.8, 2.7, 4.1, 1. ],
#        [5. , 3. , 1.6, 0.2],
#        [6.2, 2.9, 4.3, 1.3],
#        [6.2, 2.8, 4.8, 1.8],
#        [5.1, 2.5, 3. , 1.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.1, 3.4, 1.5, 0.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [5.9, 3. , 4.2, 1.5],
#        [5.2, 3.4, 1.4, 0.2],
#        [6. , 2.7, 5.1, 1.6],
#        [6.9, 3.1, 5.4, 2.1],
#        [5. , 3.5, 1.6, 0.6],
#        [7.7, 3.8, 6.7, 2.2],
#        [6.1, 3. , 4.6, 1.4],
#        [5. , 3.3, 1.4, 0.2],
#        [5.6, 2.8, 4.9, 2. ],
#        [5.1, 3.5, 1.4, 0.2],
#        [7.2, 3.2, 6. , 1.8],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.7, 2.9, 4.2, 1.3],
#        [4.4, 3. , 1.3, 0.2],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.1, 2.9, 4.7, 1.4],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.7, 3. , 5.2, 2.3],
#        [5.4, 3.7, 1.5, 0.2],
#        [6. , 3.4, 4.5, 1.6],
#        [5. , 3.5, 1.3, 0.3],
#        [5.6, 3. , 4.1, 1.3],
#        [5.5, 2.4, 3.7, 1. ],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [6.1, 2.8, 4.7, 1.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [5.5, 2.3, 4. , 1.3],
#        [7.7, 2.8, 6.7, 2. ],
#        [5.4, 3.9, 1.7, 0.4],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.6, 3. , 6.6, 2.1],
#        [6. , 2.2, 5. , 1.5],
#        [6.7, 3.1, 5.6, 2.4],
#        [5. , 3.2, 1.2, 0.2],
#        [4.6, 3.6, 1. , 0.2],
#        [5. , 2. , 3.5, 1. ],
#        [6. , 2.9, 4.5, 1.5],
#        [4.4, 3.2, 1.3, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3.4, 1.9, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [6.9, 3.1, 5.1, 2.3],
#        [4.7, 3.2, 1.3, 0.2],
#        [6.5, 2.8, 4.6, 1.5],
#        [6.7, 3. , 5. , 1.7],
#        [6.6, 3. , 4.4, 1.4],
#        [6.2, 3.4, 5.4, 2.3],
#        [6.4, 2.8, 5.6, 2.1],
#        [6.3, 3.3, 6. , 2.5],
#        [5.4, 3.9, 1.3, 0.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [5.4, 3. , 4.5, 1.5]])

# %%
X_test
# Out:
# array([[6.3, 2.7, 4.9, 1.8],
#        [6.1, 2.6, 5.6, 1.4],
#        [5.1, 3.7, 1.5, 0.4],
#        [6.3, 2.5, 5. , 1.9],
#        [5.5, 2.5, 4. , 1.3],
#        [5.2, 4.1, 1.5, 0.1],
#        [7.7, 3. , 6.1, 2.3],
#        [5.3, 3.7, 1.5, 0.2],
#        [6.4, 2.7, 5.3, 1.9],
#        [6. , 3. , 4.8, 1.8],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.1, 4.7, 1.5],
#        [5.7, 3. , 4.2, 1.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [4.8, 3.1, 1.6, 0.2],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.4, 3.4, 1.5, 0.4],
#        [7.4, 2.8, 6.1, 1.9],
#        [4.4, 2.9, 1.4, 0.2],
#        [5.7, 2.8, 4.1, 1.3],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 2.5, 4.5, 1.7],
#        [6.1, 2.8, 4. , 1.3],
#        [5.8, 4. , 1.2, 0.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [7.2, 3. , 5.8, 1.6],
#        [6.3, 3.3, 4.7, 1.6],
#        [6.4, 3.1, 5.5, 1.8],
#        [5.9, 3.2, 4.8, 1.8],
#        [5.5, 2.4, 3.8, 1.1],
#        [6.8, 3. , 5.5, 2.1],
#        [5. , 2.3, 3.3, 1. ],
#        [5.1, 3.3, 1.7, 0.5],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.7, 2.6, 3.5, 1. ],
#        [4.8, 3. , 1.4, 0.1],
#        [5.6, 3. , 4.5, 1.5],
#        [5.1, 3.8, 1.6, 0.2],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.7, 2.5, 5.8, 1.8],
#        [4.5, 2.3, 1.3, 0.3],
#        [5.8, 2.6, 4. , 1.2]])

# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
tensor_train = torch.FloatTensor(X_train).to(device)
tensor_test=torch.FloatTensor(X_test).to(device)

# %%
from autoencoder import Autoencoder
import torch.nn as nn 
import torch.optim as optim
from torch.utils.data import TensorDataset,DataLoader
inputs_dim=df.shape[1]
n_bottleneck=10
model=Autoencoder(inputs_dim,n_bottleneck).to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)
train_loader = DataLoader(TensorDataset(tensor_train, tensor_train), batch_size=64, shuffle=True)
val_loader = DataLoader(TensorDataset(tensor_test, tensor_test), batch_size=64, shuffle=False)

# %%
from tqdm import tqdm
import os

lowest_val_loss = float('inf')  # Initialize with a large value
best_epoch = 0

num_epochs = 1000
for epoch in range(num_epochs):
    # Training
    model.train()
    total_train_loss = 0.0
    with tqdm(train_loader, desc=f'Epoch {epoch + 1}/{num_epochs} - Training', unit='batch') as t:
        for batch in t:
            input_data, _ = batch
            input_data = input_data.to(device)

            optimizer.zero_grad()
            output_data = model(input_data)
            loss = criterion(output_data, input_data)
            loss.backward()
            optimizer.step()

            total_train_loss += loss.item()
            t.set_postfix(loss=f'{total_train_loss / len(train_loader):.5f}')

    # Validation
    model.eval()
    total_val_loss = 0.0
    with torch.no_grad():
        with tqdm(val_loader, desc=f'Epoch {epoch + 1}/{num_epochs} - Validation', unit='batch') as t:
            for batch in t:
                val_input_data, _ = batch
                val_input_data = val_input_data.to(device)

                val_output_data = model(val_input_data)
                val_loss = criterion(val_output_data, val_input_data)
                total_val_loss += val_loss.item()
                t.set_postfix(loss=f'{total_val_loss / len(val_loader):.5f}')

    # Save model if validation loss is the lowest
    if total_val_loss < lowest_val_loss:
        lowest_val_loss = total_val_loss
        best_epoch = epoch + 1  # Epochs are 0-indexed, so add 1

        # Save the model's state dictionary and other relevant information
        checkpoint_path = 'best_model_checkpoint_iris.pth'
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'lowest_val_loss': lowest_val_loss,
        }, checkpoint_path)

print(f"Best model found at epoch {best_epoch} with validation loss: {lowest_val_loss:.5f}")
# Out:
# Epoch 1/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 42.92batch/s, loss=15.77654]
# Epoch 1/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 213.49batch/s, loss=16.30827]
# Epoch 2/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 50.15batch/s, loss=15.50222]
# Epoch 2/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 185.04batch/s, loss=16.03125]
# Epoch 3/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 44.20batch/s, loss=15.26580]
# Epoch 3/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 280.48batch/s, loss=15.65934]
# Epoch 4/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 45.21batch/s, loss=14.80111]
# Epoch 4/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 277.75batch/s, loss=15.13847]
# Epoch 5/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 50.29batch/s, loss=14.17249]
# Epoch 5/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 371.80batch/s, loss=14.44122]
# Epoch 6/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 53.68batch/s, loss=13.62324]
# Epoch 6/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 370.36batch/s, loss=13.52861]
# Epoch 7/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 55.30batch/s, loss=12.42536]
# Epoch 7/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 340.39batch/s, loss=12.36275]
# Epoch 8/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 47.76batch/s, loss=11.42161]
# Epoch 8/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 305.24batch/s, loss=10.90085]
# Epoch 9/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 50.04batch/s, loss=10.00888]
# Epoch 9/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 286.09batch/s, loss=9.10751]
# Epoch 10/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 156.94batch/s, loss=8.20070]
# Epoch 10/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 315.20batch/s, loss=7.00417]
# Epoch 11/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 244.77batch/s, loss=6.11375]
# Epoch 11/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 655.05batch/s, loss=4.71661]
# Epoch 12/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 196.74batch/s, loss=3.93934]
# Epoch 12/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 321.62batch/s, loss=2.52934]
# Epoch 13/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 218.10batch/s, loss=1.96048]
# Epoch 13/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 186.12batch/s, loss=0.99485]
# Epoch 14/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 198.92batch/s, loss=0.81187]
# Epoch 14/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 236.03batch/s, loss=0.85532]
# Epoch 15/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 231.28batch/s, loss=1.02489]
# Epoch 15/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 3008.83batch/s, loss=1.89149]
# Epoch 16/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 209.98batch/s, loss=1.94656]
# Epoch 16/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 452.36batch/s, loss=2.24920]
# Epoch 17/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 234.33batch/s, loss=1.98751]
# Epoch 17/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 633.87batch/s, loss=1.58539]
# Epoch 18/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 191.03batch/s, loss=1.28674]
# Epoch 18/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 380.26batch/s, loss=0.86826]
# Epoch 19/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 238.64batch/s, loss=0.70309]
# Epoch 19/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 403.18batch/s, loss=0.60722]
# Epoch 20/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 232.38batch/s, loss=0.56940]
# Epoch 20/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 204.88batch/s, loss=0.71411]
# Epoch 21/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 242.77batch/s, loss=0.70226]
# Epoch 21/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 409.60batch/s, loss=0.91536]
# Epoch 22/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 248.60batch/s, loss=0.88287]
# Epoch 22/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 387.72batch/s, loss=1.02495]
# Epoch 23/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 288.58batch/s, loss=0.93172]
# Epoch 23/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 231.12batch/s, loss=0.99065]
# Epoch 24/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 239.48batch/s, loss=0.89162]
# Epoch 24/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 201.33batch/s, loss=0.85502]
# Epoch 25/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 201.73batch/s, loss=0.74930]
# Epoch 25/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.70138]
# Epoch 26/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 268.75batch/s, loss=0.60541]
# Epoch 26/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 431.47batch/s, loss=0.60948]
# Epoch 27/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 229.69batch/s, loss=0.55171]
# Epoch 27/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 360.24batch/s, loss=0.60792]
# Epoch 28/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 234.80batch/s, loss=0.54921]
# Epoch 28/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 165.41batch/s, loss=0.65780]
# Epoch 29/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 223.30batch/s, loss=0.58756]
# Epoch 29/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 471.38batch/s, loss=0.68891]
# Epoch 30/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 188.34batch/s, loss=0.62683]
# Epoch 30/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 799.83batch/s, loss=0.66735]
# Epoch 31/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 515.52batch/s, loss=0.59757]
# Epoch 31/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 614.01batch/s, loss=0.62030]
# Epoch 32/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 193.28batch/s, loss=0.55036]
# Epoch 32/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 235.74batch/s, loss=0.58906]
# Epoch 33/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 121.35batch/s, loss=0.54530]
# Epoch 33/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 300.95batch/s, loss=0.58790]
# Epoch 34/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 292.06batch/s, loss=0.55565]
# Epoch 34/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 389.88batch/s, loss=0.60270]
# Epoch 35/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 236.67batch/s, loss=0.54424]
# Epoch 35/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 134.42batch/s, loss=0.61346]
# Epoch 36/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 294.73batch/s, loss=0.56263]
# Epoch 36/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 185.52batch/s, loss=0.61002]
# Epoch 37/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 235.65batch/s, loss=0.53261]
# Epoch 37/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 170.69batch/s, loss=0.59696]
# Epoch 38/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 187.66batch/s, loss=0.53512]
# Epoch 38/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 294.09batch/s, loss=0.58460]
# Epoch 39/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 212.08batch/s, loss=0.54874]
# Epoch 39/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 734.17batch/s, loss=0.58117]
# Epoch 40/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 188.36batch/s, loss=0.55325]
# Epoch 40/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 291.82batch/s, loss=0.58538]
# Epoch 41/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 174.72batch/s, loss=0.52778]
# Epoch 41/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 500.99batch/s, loss=0.58962]
# Epoch 42/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 210.12batch/s, loss=0.53514]
# Epoch 42/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 664.08batch/s, loss=0.58881]
# Epoch 43/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 207.70batch/s, loss=0.54439]
# Epoch 43/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 271.53batch/s, loss=0.58440]
# Epoch 44/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 231.14batch/s, loss=0.52529]
# Epoch 44/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 742.09batch/s, loss=0.58104]
# Epoch 45/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 188.58batch/s, loss=0.54522]
# Epoch 45/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 458.44batch/s, loss=0.57989]
# Epoch 46/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 189.81batch/s, loss=0.49280]
# Epoch 46/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 665.02batch/s, loss=0.58030]
# Epoch 47/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 241.41batch/s, loss=0.53630]
# Epoch 47/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 194.19batch/s, loss=0.57938]
# Epoch 48/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 121.89batch/s, loss=0.51853]
# Epoch 48/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 793.77batch/s, loss=0.57745]
# Epoch 49/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 300.98batch/s, loss=0.52458]
# Epoch 49/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 762.05batch/s, loss=0.57490]
# Epoch 50/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 242.94batch/s, loss=0.52662]
# Epoch 50/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 429.52batch/s, loss=0.57331]
# Epoch 51/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 205.78batch/s, loss=0.51828]
# Epoch 51/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 902.19batch/s, loss=0.57282]
# Epoch 52/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 179.99batch/s, loss=0.50911]
# Epoch 52/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 502.97batch/s, loss=0.57280]
# Epoch 53/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 230.56batch/s, loss=0.53080]
# Epoch 53/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 186.55batch/s, loss=0.57207]
# Epoch 54/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 238.11batch/s, loss=0.50481]
# Epoch 54/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 321.01batch/s, loss=0.57129]
# Epoch 55/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 145.47batch/s, loss=0.51993]
# Epoch 55/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.57047]
# Epoch 56/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 244.44batch/s, loss=0.53972]
# Epoch 56/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 158.23batch/s, loss=0.57018]
# Epoch 57/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 203.37batch/s, loss=0.51802]
# Epoch 57/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 744.20batch/s, loss=0.57045]
# Epoch 58/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 215.18batch/s, loss=0.52641]
# Epoch 58/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 302.79batch/s, loss=0.57037]
# Epoch 59/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 215.09batch/s, loss=0.49731]
# Epoch 59/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 163.27batch/s, loss=0.56994]
# Epoch 60/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 216.46batch/s, loss=0.52758]
# Epoch 60/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 467.33batch/s, loss=0.56802]
# Epoch 61/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 124.74batch/s, loss=0.50137]
# Epoch 61/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 452.70batch/s, loss=0.56633]
# Epoch 62/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 244.49batch/s, loss=0.52514]
# Epoch 62/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 262.21batch/s, loss=0.56469]
# Epoch 63/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 193.18batch/s, loss=0.51836]
# Epoch 63/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 650.99batch/s, loss=0.56326]
# Epoch 64/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 277.37batch/s, loss=0.49767]
# Epoch 64/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 148.99batch/s, loss=0.56188]
# Epoch 65/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 227.66batch/s, loss=0.51119]
# Epoch 65/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 346.29batch/s, loss=0.56030]
# Epoch 66/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 142.72batch/s, loss=0.52347]
# Epoch 66/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 388.97batch/s, loss=0.55884]
# Epoch 67/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 206.25batch/s, loss=0.49837]
# Epoch 67/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 393.91batch/s, loss=0.55765]
# Epoch 68/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 172.85batch/s, loss=0.49959]
# Epoch 68/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 470.85batch/s, loss=0.55629]
# Epoch 69/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 228.29batch/s, loss=0.50117]
# Epoch 69/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.55431]
# Epoch 70/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 187.33batch/s, loss=0.49669]
# Epoch 70/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 292.55batch/s, loss=0.55197]
# Epoch 71/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 233.33batch/s, loss=0.48649]
# Epoch 71/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 291.13batch/s, loss=0.54972]
# Epoch 72/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 180.34batch/s, loss=0.50394]
# Epoch 72/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 369.38batch/s, loss=0.54731]
# Epoch 73/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 196.35batch/s, loss=0.49469]
# Epoch 73/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 340.53batch/s, loss=0.54500]
# Epoch 74/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 183.16batch/s, loss=0.50541]
# Epoch 74/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 874.36batch/s, loss=0.54251]
# Epoch 75/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 352.54batch/s, loss=0.48173]
# Epoch 75/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 124.85batch/s, loss=0.54011]
# Epoch 76/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 197.03batch/s, loss=0.49656]
# Epoch 76/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 728.56batch/s, loss=0.53719]
# Epoch 77/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 205.04batch/s, loss=0.47669]
# Epoch 77/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.53429]
# Epoch 78/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 192.51batch/s, loss=0.47949]
# Epoch 78/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 481.66batch/s, loss=0.53104]
# Epoch 79/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 192.30batch/s, loss=0.47700]
# Epoch 79/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 374.63batch/s, loss=0.52725]
# Epoch 80/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 214.13batch/s, loss=0.48220]
# Epoch 80/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 302.64batch/s, loss=0.52262]
# Epoch 81/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 237.96batch/s, loss=0.46397]
# Epoch 81/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 802.43batch/s, loss=0.51725]
# Epoch 82/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 252.34batch/s, loss=0.44820]
# Epoch 82/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 434.24batch/s, loss=0.51111]
# Epoch 83/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 152.87batch/s, loss=0.46668]
# Epoch 83/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.50462]
# Epoch 84/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 187.04batch/s, loss=0.44570]
# Epoch 84/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 398.40batch/s, loss=0.49749]
# Epoch 85/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 244.53batch/s, loss=0.44048]
# Epoch 85/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.48974]
# Epoch 86/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 178.74batch/s, loss=0.43400]
# Epoch 86/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.48131]
# Epoch 87/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 227.86batch/s, loss=0.41884]
# Epoch 87/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 315.01batch/s, loss=0.47238]
# Epoch 88/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 123.84batch/s, loss=0.42466]
# Epoch 88/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 249.77batch/s, loss=0.46155]
# Epoch 89/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 197.88batch/s, loss=0.40622]
# Epoch 89/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 380.44batch/s, loss=0.45020]
# Epoch 90/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 204.90batch/s, loss=0.39802]
# Epoch 90/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 399.76batch/s, loss=0.43685]
# Epoch 91/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 212.65batch/s, loss=0.39476]
# Epoch 91/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 521.10batch/s, loss=0.42238]
# Epoch 92/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 144.75batch/s, loss=0.38032]
# Epoch 92/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.40631]
# Epoch 93/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 146.01batch/s, loss=0.36768]
# Epoch 93/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.38841]
# Epoch 94/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 193.89batch/s, loss=0.33438]
# Epoch 94/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 395.28batch/s, loss=0.36888]
# Epoch 95/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 214.87batch/s, loss=0.32690]
# Epoch 95/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 824.51batch/s, loss=0.34776]
# Epoch 96/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 209.87batch/s, loss=0.31159]
# Epoch 96/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 584.98batch/s, loss=0.32519]
# Epoch 97/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 171.21batch/s, loss=0.28553]
# Epoch 97/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 486.58batch/s, loss=0.30067]
# Epoch 98/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 121.38batch/s, loss=0.27153]
# Epoch 98/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.27410]
# Epoch 99/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 198.14batch/s, loss=0.24201]
# Epoch 99/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 393.43batch/s, loss=0.24522]
# Epoch 100/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 426.94batch/s, loss=0.21153]
# Epoch 100/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 768.19batch/s, loss=0.21431]
# Epoch 101/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 231.44batch/s, loss=0.18107]
# Epoch 101/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 680.34batch/s, loss=0.18308]
# Epoch 102/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 220.76batch/s, loss=0.15475]
# Epoch 102/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 451.10batch/s, loss=0.15206]
# Epoch 103/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 242.85batch/s, loss=0.12784]
# Epoch 103/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 642.90batch/s, loss=0.12138]
# Epoch 104/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 184.90batch/s, loss=0.09829]
# Epoch 104/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 238.00batch/s, loss=0.09285]
# Epoch 105/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 207.40batch/s, loss=0.07537]
# Epoch 105/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 193.29batch/s, loss=0.06818]
# Epoch 106/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 211.84batch/s, loss=0.05604]
# Epoch 106/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 398.70batch/s, loss=0.04939]
# Epoch 107/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 239.37batch/s, loss=0.04330]
# Epoch 107/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 405.52batch/s, loss=0.03736]
# Epoch 108/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 282.44batch/s, loss=0.03274]
# Epoch 108/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 459.15batch/s, loss=0.03152]
# Epoch 109/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 105.89batch/s, loss=0.03134]
# Epoch 109/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 404.93batch/s, loss=0.03104]
# Epoch 110/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 105.42batch/s, loss=0.03215]
# Epoch 110/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 185.20batch/s, loss=0.03287]
# Epoch 111/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 98.77batch/s, loss=0.03449]
# Epoch 111/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 429.61batch/s, loss=0.03458]
# Epoch 112/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 141.43batch/s, loss=0.03572]
# Epoch 112/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 366.12batch/s, loss=0.03472]
# Epoch 113/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 115.25batch/s, loss=0.03554]
# Epoch 113/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 341.25batch/s, loss=0.03352]
# Epoch 114/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 106.37batch/s, loss=0.03349]
# Epoch 114/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 756.14batch/s, loss=0.03207]
# Epoch 115/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 111.25batch/s, loss=0.03352]
# Epoch 115/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 416.27batch/s, loss=0.03046]
# Epoch 116/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 147.69batch/s, loss=0.03223]
# Epoch 116/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 313.99batch/s, loss=0.02999]
# Epoch 117/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 135.48batch/s, loss=0.02994]
# Epoch 117/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 1600.27batch/s, loss=0.03001]
# Epoch 118/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 121.13batch/s, loss=0.02938]
# Epoch 118/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 330.62batch/s, loss=0.03036]
# Epoch 119/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 104.10batch/s, loss=0.02932]
# Epoch 119/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 245.38batch/s, loss=0.03042]
# Epoch 120/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 110.22batch/s, loss=0.02875]
# Epoch 120/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 269.44batch/s, loss=0.03034]
# Epoch 121/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 120.14batch/s, loss=0.02874]
# Epoch 121/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 750.73batch/s, loss=0.03031]
# Epoch 122/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 280.84batch/s, loss=0.03073]
# Epoch 122/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 442.58batch/s, loss=0.03034]
# Epoch 123/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 243.20batch/s, loss=0.03158]
# Epoch 123/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 711.99batch/s, loss=0.03015]
# Epoch 124/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 367.44batch/s, loss=0.02919]
# Epoch 124/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 526.59batch/s, loss=0.02992]
# Epoch 125/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 134.60batch/s, loss=0.02745]
# Epoch 125/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 330.21batch/s, loss=0.02965]
# Epoch 126/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 213.33batch/s, loss=0.02917]
# Epoch 126/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 456.70batch/s, loss=0.02938]
# Epoch 127/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 258.51batch/s, loss=0.02877]
# Epoch 127/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 422.47batch/s, loss=0.02893]
# Epoch 128/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 164.07batch/s, loss=0.02786]
# Epoch 128/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 297.22batch/s, loss=0.02868]
# Epoch 129/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 179.71batch/s, loss=0.02634]
# Epoch 129/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 400.76batch/s, loss=0.02845]
# Epoch 130/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 221.24batch/s, loss=0.02748]
# Epoch 130/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 531.26batch/s, loss=0.02836]
# Epoch 131/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 295.79batch/s, loss=0.02858]
# Epoch 131/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 376.17batch/s, loss=0.02825]
# Epoch 132/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 136.73batch/s, loss=0.02717]
# Epoch 132/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 522.39batch/s, loss=0.02822]
# Epoch 133/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 121.24batch/s, loss=0.02938]
# Epoch 133/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 476.73batch/s, loss=0.02814]
# Epoch 134/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 191.37batch/s, loss=0.02725]
# Epoch 134/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 855.98batch/s, loss=0.02813]
# Epoch 135/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 214.20batch/s, loss=0.02868]
# Epoch 135/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.02817]
# Epoch 136/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 226.74batch/s, loss=0.02900]
# Epoch 136/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.02805]
# Epoch 137/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 243.90batch/s, loss=0.02913]
# Epoch 137/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 183.67batch/s, loss=0.02803]
# Epoch 138/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 244.69batch/s, loss=0.02723]
# Epoch 138/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 768.89batch/s, loss=0.02822]
# Epoch 139/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 171.76batch/s, loss=0.02628]
# Epoch 139/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 134.89batch/s, loss=0.02820]
# Epoch 140/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 186.88batch/s, loss=0.02615]
# Epoch 140/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 648.57batch/s, loss=0.02822]
# Epoch 141/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 515.49batch/s, loss=0.02647]
# Epoch 141/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 100.61batch/s, loss=0.02824]
# Epoch 142/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 175.68batch/s, loss=0.02778]
# Epoch 142/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 297.70batch/s, loss=0.02818]
# Epoch 143/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 197.06batch/s, loss=0.02818]
# Epoch 143/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 2761.23batch/s, loss=0.02801]
# Epoch 144/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 187.34batch/s, loss=0.02896]
# Epoch 144/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 255.58batch/s, loss=0.02778]
# Epoch 145/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 214.72batch/s, loss=0.02612]
# Epoch 145/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.02780]
# Epoch 146/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 195.83batch/s, loss=0.02682]
# Epoch 146/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 643.20batch/s, loss=0.02777]
# Epoch 147/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 189.81batch/s, loss=0.02765]
# Epoch 147/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 372.93batch/s, loss=0.02774]
# Epoch 148/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 194.98batch/s, loss=0.02791]
# Epoch 148/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 348.31batch/s, loss=0.02778]
# Epoch 149/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 252.19batch/s, loss=0.02776]
# Epoch 149/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 371.74batch/s, loss=0.02788]
# Epoch 150/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 241.93batch/s, loss=0.02735]
# Epoch 150/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 211.52batch/s, loss=0.02797]
# Epoch 151/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 162.54batch/s, loss=0.02571]
# Epoch 151/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 316.41batch/s, loss=0.02777]
# Epoch 152/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 194.88batch/s, loss=0.02724]
# Epoch 152/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 209.56batch/s, loss=0.02753]
# Epoch 153/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 213.03batch/s, loss=0.02558]
# Epoch 153/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 255.31batch/s, loss=0.02730]
# Epoch 154/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 285.16batch/s, loss=0.02744]
# Epoch 154/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 641.53batch/s, loss=0.02730]
# Epoch 155/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 169.55batch/s, loss=0.02740]
# Epoch 155/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 206.11batch/s, loss=0.02731]
# Epoch 156/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 214.74batch/s, loss=0.02647]
# Epoch 156/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 249.44batch/s, loss=0.02748]
# Epoch 157/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 209.09batch/s, loss=0.02706]
# Epoch 157/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 427.55batch/s, loss=0.02749]
# Epoch 158/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 227.86batch/s, loss=0.02750]
# Epoch 158/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 256.94batch/s, loss=0.02750]
# Epoch 159/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 173.19batch/s, loss=0.02703]
# Epoch 159/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 301.27batch/s, loss=0.02745]
# Epoch 160/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 273.41batch/s, loss=0.02541]
# Epoch 160/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 1081.01batch/s, loss=0.02745]
# Epoch 161/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 210.64batch/s, loss=0.02723]
# Epoch 161/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 891.65batch/s, loss=0.02735]
# Epoch 162/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 225.68batch/s, loss=0.02655]
# Epoch 162/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 173.12batch/s, loss=0.02715]
# Epoch 163/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 210.17batch/s, loss=0.02657]
# Epoch 163/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 439.06batch/s, loss=0.02705]
# Epoch 164/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 113.01batch/s, loss=0.02538]
# Epoch 164/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 171.13batch/s, loss=0.02709]
# Epoch 165/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 172.60batch/s, loss=0.02648]
# Epoch 165/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 383.11batch/s, loss=0.02714]
# Epoch 166/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 151.44batch/s, loss=0.02499]
# Epoch 166/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 269.61batch/s, loss=0.02712]
# Epoch 167/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 161.38batch/s, loss=0.02645]
# Epoch 167/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 412.14batch/s, loss=0.02717]
# Epoch 168/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 177.79batch/s, loss=0.02575]
# Epoch 168/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 273.19batch/s, loss=0.02737]
# Epoch 169/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 229.41batch/s, loss=0.02585]
# Epoch 169/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 391.41batch/s, loss=0.02742]
# Epoch 170/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 201.18batch/s, loss=0.02523]
# Epoch 170/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 356.60batch/s, loss=0.02747]
# Epoch 171/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 231.38batch/s, loss=0.02628]
# Epoch 171/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 357.81batch/s, loss=0.02747]
# Epoch 172/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 169.86batch/s, loss=0.02534]
# Epoch 172/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 1156.41batch/s, loss=0.02740]
# Epoch 173/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 192.58batch/s, loss=0.02504]
# Epoch 173/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 329.64batch/s, loss=0.02715]
# Epoch 174/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 246.77batch/s, loss=0.02681]
# Epoch 174/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 306.56batch/s, loss=0.02691]
# Epoch 175/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 233.30batch/s, loss=0.02527]
# Epoch 175/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 535.47batch/s, loss=0.02693]
# Epoch 176/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 161.09batch/s, loss=0.02607]
# Epoch 176/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 235.74batch/s, loss=0.02685]
# Epoch 177/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 177.17batch/s, loss=0.02520]
# Epoch 177/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 420.52batch/s, loss=0.02697]
# Epoch 178/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 183.13batch/s, loss=0.02581]
# Epoch 178/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.02733]
# Epoch 179/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 186.21batch/s, loss=0.02683]
# Epoch 179/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 425.26batch/s, loss=0.02731]
# Epoch 180/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 176.01batch/s, loss=0.02706]
# Epoch 180/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 467.85batch/s, loss=0.02736]
# Epoch 181/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 190.39batch/s, loss=0.02538]
# Epoch 181/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 1368.90batch/s, loss=0.02719]
# Epoch 182/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 212.30batch/s, loss=0.02645]
# Epoch 182/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 179.44batch/s, loss=0.02712]
# Epoch 183/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 161.04batch/s, loss=0.02581]
# Epoch 183/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 390.35batch/s, loss=0.02698]
# Epoch 184/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 239.63batch/s, loss=0.02582]
# Epoch 184/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.02694]
# Epoch 185/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 240.55batch/s, loss=0.02567]
# Epoch 185/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 219.82batch/s, loss=0.02709]
# Epoch 186/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 203.73batch/s, loss=0.02458]
# Epoch 186/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 262.78batch/s, loss=0.02711]
# Epoch 187/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 198.60batch/s, loss=0.02581]
# Epoch 187/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 458.59batch/s, loss=0.02716]
# Epoch 188/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 194.55batch/s, loss=0.02618]
# Epoch 188/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 406.19batch/s, loss=0.02753]
# Epoch 189/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 207.48batch/s, loss=0.02549]
# Epoch 189/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 520.06batch/s, loss=0.02757]
# Epoch 190/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 170.57batch/s, loss=0.02424]
# Epoch 190/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 940.01batch/s, loss=0.02747]
# Epoch 191/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 221.15batch/s, loss=0.02372]
# Epoch 191/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 1765.28batch/s, loss=0.02726]
# Epoch 192/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 264.74batch/s, loss=0.02490]
# Epoch 192/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 258.54batch/s, loss=0.02704]
# Epoch 193/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 179.48batch/s, loss=0.02506]
# Epoch 193/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 236.25batch/s, loss=0.02694]
# Epoch 194/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 187.61batch/s, loss=0.02591]
# Epoch 194/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 454.08batch/s, loss=0.02683]
# Epoch 195/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 247.08batch/s, loss=0.02462]
# Epoch 195/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 368.60batch/s, loss=0.02688]
# Epoch 196/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 229.16batch/s, loss=0.02560]
# Epoch 196/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 379.09batch/s, loss=0.02676]
# Epoch 197/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 203.16batch/s, loss=0.02609]
# Epoch 197/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 327.32batch/s, loss=0.02674]
# Epoch 198/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 181.83batch/s, loss=0.02466]
# Epoch 198/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 296.27batch/s, loss=0.02706]
# Epoch 199/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 167.93batch/s, loss=0.02355]
# Epoch 199/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 398.55batch/s, loss=0.02759]
# Epoch 200/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 215.20batch/s, loss=0.02403]
# Epoch 200/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 790.48batch/s, loss=0.02754]
# Epoch 201/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 242.50batch/s, loss=0.02414]
# Epoch 201/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.02699]
# Epoch 202/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 120.37batch/s, loss=0.02496]
# Epoch 202/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.02683]
# Epoch 203/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 446.18batch/s, loss=0.02452]
# Epoch 203/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 110.27batch/s, loss=0.02668]
# Epoch 204/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 244.29batch/s, loss=0.02412]
# Epoch 204/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 233.16batch/s, loss=0.02659]
# Epoch 205/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 224.37batch/s, loss=0.02545]
# Epoch 205/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 258.99batch/s, loss=0.02672]
# Epoch 206/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 110.21batch/s, loss=0.02604]
# Epoch 206/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 211.42batch/s, loss=0.02701]
# Epoch 207/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 149.19batch/s, loss=0.02379]
# Epoch 207/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 328.58batch/s, loss=0.02766]
# Epoch 208/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 181.91batch/s, loss=0.02436]
# Epoch 208/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 777.73batch/s, loss=0.02789]
# Epoch 209/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 303.36batch/s, loss=0.02509]
# Epoch 209/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 182.05batch/s, loss=0.02752]
# Epoch 210/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 208.66batch/s, loss=0.02513]
# Epoch 210/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 734.43batch/s, loss=0.02686]
# Epoch 211/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 198.74batch/s, loss=0.02369]
# Epoch 211/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.02679]
# Epoch 212/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 169.28batch/s, loss=0.02575]
# Epoch 212/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 293.43batch/s, loss=0.02682]
# Epoch 213/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 206.80batch/s, loss=0.02443]
# Epoch 213/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 777.30batch/s, loss=0.02702]
# Epoch 214/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 394.57batch/s, loss=0.02520]
# Epoch 214/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 115.25batch/s, loss=0.02727]
# Epoch 215/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 110.97batch/s, loss=0.02414]
# Epoch 215/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 877.10batch/s, loss=0.02722]
# Epoch 216/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 190.52batch/s, loss=0.02455]
# Epoch 216/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 169.19batch/s, loss=0.02709]
# Epoch 217/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 250.93batch/s, loss=0.02523]
# Epoch 217/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 136.44batch/s, loss=0.02682]
# Epoch 218/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 229.06batch/s, loss=0.02501]
# Epoch 218/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 861.61batch/s, loss=0.02675]
# Epoch 219/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 193.38batch/s, loss=0.02526]
# Epoch 219/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.02683]
# Epoch 220/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 216.04batch/s, loss=0.02433]
# Epoch 220/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 262.95batch/s, loss=0.02708]
# Epoch 221/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 211.22batch/s, loss=0.02408]
# Epoch 221/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 803.20batch/s, loss=0.02736]
# Epoch 222/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 186.29batch/s, loss=0.02457]
# Epoch 222/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 380.82batch/s, loss=0.02736]
# Epoch 223/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 188.52batch/s, loss=0.02436]
# Epoch 223/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 459.60batch/s, loss=0.02718]
# Epoch 224/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 245.76batch/s, loss=0.02399]
# Epoch 224/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.02719]
# Epoch 225/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 191.17batch/s, loss=0.02392]
# Epoch 225/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 866.95batch/s, loss=0.02715]
# Epoch 226/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 182.20batch/s, loss=0.02403]
# Epoch 226/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 201.07batch/s, loss=0.02704]
# Epoch 227/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 131.08batch/s, loss=0.02308]
# Epoch 227/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 256.83batch/s, loss=0.02699]
# Epoch 228/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 148.95batch/s, loss=0.02299]
# Epoch 228/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 196.48batch/s, loss=0.02687]
# Epoch 229/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 154.53batch/s, loss=0.02419]
# Epoch 229/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 749.25batch/s, loss=0.02715]
# Epoch 230/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 185.55batch/s, loss=0.02234]
# Epoch 230/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 402.95batch/s, loss=0.02711]
# Epoch 231/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 229.98batch/s, loss=0.02285]
# Epoch 231/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 275.61batch/s, loss=0.02711]
# Epoch 232/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 179.37batch/s, loss=0.02296]
# Epoch 232/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 781.50batch/s, loss=0.02705]
# Epoch 233/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 183.18batch/s, loss=0.02373]
# Epoch 233/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 354.76batch/s, loss=0.02720]
# Epoch 234/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 224.97batch/s, loss=0.02384]
# Epoch 234/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 757.23batch/s, loss=0.02747]
# Epoch 235/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 215.40batch/s, loss=0.02319]
# Epoch 235/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 338.88batch/s, loss=0.02756]
# Epoch 236/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 351.53batch/s, loss=0.02380]
# Epoch 236/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 147.93batch/s, loss=0.02755]
# Epoch 237/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 276.45batch/s, loss=0.02475]
# Epoch 237/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 388.15batch/s, loss=0.02746]
# Epoch 238/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 186.87batch/s, loss=0.02320]
# Epoch 238/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 519.23batch/s, loss=0.02713]
# Epoch 239/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 186.47batch/s, loss=0.02193]
# Epoch 239/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 211.88batch/s, loss=0.02704]
# Epoch 240/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 165.00batch/s, loss=0.02401]
# Epoch 240/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 417.09batch/s, loss=0.02710]
# Epoch 241/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 209.83batch/s, loss=0.02355]
# Epoch 241/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 808.31batch/s, loss=0.02735]
# Epoch 242/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 238.31batch/s, loss=0.02276]
# Epoch 242/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.02751]
# Epoch 243/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 220.71batch/s, loss=0.02252]
# Epoch 243/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 376.20batch/s, loss=0.02790]
# Epoch 244/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 178.17batch/s, loss=0.02366]
# Epoch 244/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 679.68batch/s, loss=0.02799]
# Epoch 245/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 231.58batch/s, loss=0.02230]
# Epoch 245/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 338.28batch/s, loss=0.02753]
# Epoch 246/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 209.35batch/s, loss=0.02287]
# Epoch 246/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 238.03batch/s, loss=0.02720]
# Epoch 247/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 176.94batch/s, loss=0.02417]
# Epoch 247/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 625.36batch/s, loss=0.02721]
# Epoch 248/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 199.94batch/s, loss=0.02379]
# Epoch 248/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 125.17batch/s, loss=0.02731]
# Epoch 249/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 141.92batch/s, loss=0.02290]
# Epoch 249/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 311.33batch/s, loss=0.02737]
# Epoch 250/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 173.59batch/s, loss=0.02338]
# Epoch 250/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 399.99batch/s, loss=0.02745]
# Epoch 251/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 285.35batch/s, loss=0.02279]
# Epoch 251/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 901.61batch/s, loss=0.02755]
# Epoch 252/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 229.67batch/s, loss=0.02502]
# Epoch 252/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.02768]
# Epoch 253/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 195.57batch/s, loss=0.02312]
# Epoch 253/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 650.18batch/s, loss=0.02727]
# Epoch 254/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 295.25batch/s, loss=0.02396]
# Epoch 254/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 120.42batch/s, loss=0.02740]
# Epoch 255/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 189.89batch/s, loss=0.02404]
# Epoch 255/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 813.32batch/s, loss=0.02747]
# Epoch 256/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 192.32batch/s, loss=0.02326]
# Epoch 256/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 546.28batch/s, loss=0.02752]
# Epoch 257/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 140.18batch/s, loss=0.02339]
# Epoch 257/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 390.06batch/s, loss=0.02756]
# Epoch 258/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 225.61batch/s, loss=0.02257]
# Epoch 258/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.02781]
# Epoch 259/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 195.02batch/s, loss=0.02225]
# Epoch 259/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.02808]
# Epoch 260/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 192.05batch/s, loss=0.02338]
# Epoch 260/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 348.34batch/s, loss=0.02828]
# Epoch 261/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 195.88batch/s, loss=0.02258]
# Epoch 261/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 470.32batch/s, loss=0.02765]
# Epoch 262/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 231.80batch/s, loss=0.02278]
# Epoch 262/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 461.72batch/s, loss=0.02720]
# Epoch 263/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 189.84batch/s, loss=0.02378]
# Epoch 263/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 519.16batch/s, loss=0.02712]
# ...
# Epoch 913/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 158.20batch/s, loss=0.00231]
# Epoch 913/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 361.17batch/s, loss=0.00352]
# Epoch 914/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 121.98batch/s, loss=0.00279]
# Epoch 914/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.00342]
# Epoch 915/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 180.04batch/s, loss=0.00237]
# Epoch 915/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 448.78batch/s, loss=0.00344]
# Epoch 916/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 305.20batch/s, loss=0.00233]
# Epoch 916/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 398.13batch/s, loss=0.00363]
# Epoch 917/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 321.11batch/s, loss=0.00229]
# Epoch 917/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 318.45batch/s, loss=0.00344]
# Epoch 918/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 142.66batch/s, loss=0.00206]
# Epoch 918/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 333.30batch/s, loss=0.00327]
# Epoch 919/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 164.00batch/s, loss=0.00234]
# Epoch 919/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 462.39batch/s, loss=0.00326]
# Epoch 920/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 180.34batch/s, loss=0.00238]
# Epoch 920/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 792.28batch/s, loss=0.00326]
# Epoch 921/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 131.09batch/s, loss=0.00227]
# Epoch 921/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.00308]
# Epoch 922/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 172.76batch/s, loss=0.00200]
# Epoch 922/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 333.25batch/s, loss=0.00323]
# Epoch 923/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 194.37batch/s, loss=0.00255]
# Epoch 923/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.00308]
# Epoch 924/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 217.32batch/s, loss=0.00201]
# Epoch 924/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 150.58batch/s, loss=0.00311]
# Epoch 925/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 215.04batch/s, loss=0.00236]
# Epoch 925/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 136.97batch/s, loss=0.00306]
# Epoch 926/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 162.05batch/s, loss=0.00196]
# Epoch 926/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.00299]
# Epoch 927/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 161.78batch/s, loss=0.00188]
# Epoch 927/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 618.26batch/s, loss=0.00288]
# Epoch 928/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 204.02batch/s, loss=0.00198]
# Epoch 928/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.00283]
# Epoch 929/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 120.46batch/s, loss=0.00182]
# Epoch 929/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 500.10batch/s, loss=0.00304]
# Epoch 930/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 185.65batch/s, loss=0.00166]
# Epoch 930/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 499.98batch/s, loss=0.00281]
# Epoch 931/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 162.62batch/s, loss=0.00164]
# Epoch 931/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 447.87batch/s, loss=0.00264]
# Epoch 932/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 175.71batch/s, loss=0.00182]
# Epoch 932/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 348.42batch/s, loss=0.00271]
# Epoch 933/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 144.27batch/s, loss=0.00182]
# Epoch 933/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.00266]
# Epoch 934/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 177.38batch/s, loss=0.00168]
# Epoch 934/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 481.22batch/s, loss=0.00255]
# Epoch 935/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 152.19batch/s, loss=0.00161]
# Epoch 935/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.00270]
# Epoch 936/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 119.48batch/s, loss=0.00169]
# Epoch 936/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 419.68batch/s, loss=0.00250]
# Epoch 937/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 122.26batch/s, loss=0.00170]
# Epoch 937/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.00245]
# Epoch 938/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 190.45batch/s, loss=0.00145]
# Epoch 938/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 797.24batch/s, loss=0.00266]
# Epoch 939/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 136.99batch/s, loss=0.00146]
# Epoch 939/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 399.34batch/s, loss=0.00237]
# Epoch 940/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 159.32batch/s, loss=0.00159]
# Epoch 940/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 333.28batch/s, loss=0.00236]
# Epoch 941/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 359.09batch/s, loss=0.00131]
# Epoch 941/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 212.20batch/s, loss=0.00228]
# Epoch 942/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 141.25batch/s, loss=0.00133]
# Epoch 942/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 544.29batch/s, loss=0.00229]
# Epoch 943/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 167.03batch/s, loss=0.00128]
# Epoch 943/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.00223]
# Epoch 944/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 125.86batch/s, loss=0.00130]
# Epoch 944/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.00215]
# Epoch 945/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 176.94batch/s, loss=0.00114]
# Epoch 945/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 325.82batch/s, loss=0.00221]
# Epoch 946/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 160.26batch/s, loss=0.00118]
# Epoch 946/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 435.23batch/s, loss=0.00211]
# Epoch 947/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 113.97batch/s, loss=0.00118]
# Epoch 947/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.00203]
# Epoch 948/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 170.68batch/s, loss=0.00110]
# Epoch 948/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.00205]
# Epoch 949/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 205.25batch/s, loss=0.00116]
# Epoch 949/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.00199]
# Epoch 950/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 160.19batch/s, loss=0.00112]
# Epoch 950/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.00193]
# Epoch 951/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 163.12batch/s, loss=0.00111]
# Epoch 951/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 794.07batch/s, loss=0.00205]
# Epoch 952/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 137.97batch/s, loss=0.00113]
# Epoch 952/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 821.61batch/s, loss=0.00190]
# Epoch 953/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 96.15batch/s, loss=0.00101]
# Epoch 953/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 333.17batch/s, loss=0.00195]
# Epoch 954/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 103.37batch/s, loss=0.00109]
# Epoch 954/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 499.92batch/s, loss=0.00176]
# Epoch 955/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 110.84batch/s, loss=0.00098]
# Epoch 955/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.00198]
# Epoch 956/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 100.40batch/s, loss=0.00103]
# Epoch 956/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 332.62batch/s, loss=0.00173]
# Epoch 957/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 86.70batch/s, loss=0.00091]
# Epoch 957/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 264.22batch/s, loss=0.00167]
# Epoch 958/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 101.18batch/s, loss=0.00090]
# Epoch 958/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 389.12batch/s, loss=0.00175]
# Epoch 959/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 118.59batch/s, loss=0.00087]
# Epoch 959/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.00164]
# Epoch 960/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 119.83batch/s, loss=0.00083]
# Epoch 960/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 121.03batch/s, loss=0.00165]
# Epoch 961/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 106.66batch/s, loss=0.00089]
# Epoch 961/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 379.30batch/s, loss=0.00157]
# Epoch 962/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 105.23batch/s, loss=0.00076]
# Epoch 962/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 499.92batch/s, loss=0.00152]
# Epoch 963/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 82.07batch/s, loss=0.00074]
# Epoch 963/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 331.23batch/s, loss=0.00156]
# Epoch 964/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 104.33batch/s, loss=0.00080]
# Epoch 964/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.00148]
# Epoch 965/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 101.39batch/s, loss=0.00076]
# Epoch 965/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 332.72batch/s, loss=0.00152]
# Epoch 966/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 108.44batch/s, loss=0.00069]
# Epoch 966/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 332.62batch/s, loss=0.00152]
# Epoch 967/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 107.60batch/s, loss=0.00065]
# Epoch 967/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.00142]
# Epoch 968/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 123.17batch/s, loss=0.00064]
# Epoch 968/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 113.07batch/s, loss=0.00145]
# Epoch 969/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 100.58batch/s, loss=0.00069]
# Epoch 969/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 493.22batch/s, loss=0.00134]
# Epoch 970/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 108.04batch/s, loss=0.00067]
# Epoch 970/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 360.00batch/s, loss=0.00135]
# Epoch 971/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 118.47batch/s, loss=0.00067]
# Epoch 971/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 141.35batch/s, loss=0.00132]
# Epoch 972/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 83.16batch/s, loss=0.00059]
# Epoch 972/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 333.15batch/s, loss=0.00129]
# Epoch 973/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 86.44batch/s, loss=0.00053]
# Epoch 973/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.00133]
# Epoch 974/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 100.52batch/s, loss=0.00057]
# Epoch 974/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 342.00batch/s, loss=0.00126]
# Epoch 975/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 116.87batch/s, loss=0.00058]
# Epoch 975/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 481.77batch/s, loss=0.00124]
# Epoch 976/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 114.59batch/s, loss=0.00053]
# Epoch 976/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 499.92batch/s, loss=0.00129]
# Epoch 977/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 117.55batch/s, loss=0.00056]
# Epoch 977/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 280.84batch/s, loss=0.00121]
# Epoch 978/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 94.26batch/s, loss=0.00058]
# Epoch 978/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 495.20batch/s, loss=0.00122]
# Epoch 979/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 111.04batch/s, loss=0.00048]
# Epoch 979/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.00126]
# Epoch 980/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 74.81batch/s, loss=0.00054]
# Epoch 980/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 334.85batch/s, loss=0.00116]
# Epoch 981/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 103.92batch/s, loss=0.00044]
# Epoch 981/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.00128]
# Epoch 982/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 121.52batch/s, loss=0.00048]
# Epoch 982/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.00114]
# Epoch 983/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 102.09batch/s, loss=0.00048]
# Epoch 983/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.00118]
# Epoch 984/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 133.39batch/s, loss=0.00044]
# Epoch 984/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.00107]
# Epoch 985/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 296.74batch/s, loss=0.00040]
# Epoch 985/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 133.26batch/s, loss=0.00108]
# Epoch 986/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 202.57batch/s, loss=0.00036]
# Epoch 986/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.00111]
# Epoch 987/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 229.99batch/s, loss=0.00038]
# Epoch 987/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.00107]
# Epoch 988/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 112.31batch/s, loss=0.00039]
# Epoch 988/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 367.73batch/s, loss=0.00114]
# Epoch 989/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 192.61batch/s, loss=0.00050]
# Epoch 989/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 498.79batch/s, loss=0.00107]
# Epoch 990/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 229.34batch/s, loss=0.00047]
# Epoch 990/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 596.97batch/s, loss=0.00105]
# Epoch 991/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 140.84batch/s, loss=0.00036]
# Epoch 991/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 195.57batch/s, loss=0.00102]
# Epoch 992/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 188.09batch/s, loss=0.00037]
# Epoch 992/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 417.05batch/s, loss=0.00111]
# Epoch 993/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 174.97batch/s, loss=0.00037]
# Epoch 993/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 319.47batch/s, loss=0.00107]
# Epoch 994/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 190.56batch/s, loss=0.00037]
# Epoch 994/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 495.66batch/s, loss=0.00117]
# Epoch 995/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 213.16batch/s, loss=0.00042]
# Epoch 995/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.00103]
# Epoch 996/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 120.88batch/s, loss=0.00037]
# Epoch 996/1000 - Validation: 100%|██████████| 1/1 [00:00<?, ?batch/s, loss=0.00104]
# Epoch 997/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 122.74batch/s, loss=0.00033]
# Epoch 997/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 333.30batch/s, loss=0.00094]
# Epoch 998/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 206.19batch/s, loss=0.00035]
# Epoch 998/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 333.23batch/s, loss=0.00094]
# Epoch 999/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 137.21batch/s, loss=0.00032]
# Epoch 999/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 333.25batch/s, loss=0.00097]
# Epoch 1000/1000 - Training: 100%|██████████| 2/2 [00:00<00:00, 222.73batch/s, loss=0.00030]
# Epoch 1000/1000 - Validation: 100%|██████████| 1/1 [00:00<00:00, 118.69batch/s, loss=0.00090]
# Best model found at epoch 1000 with validation loss: 0.00090

# %%
checkpoint_path = 'best_model_checkpoint_iris.pth'
checkpoint = torch.load(checkpoint_path)
model = Autoencoder(inputs_dim, n_bottleneck).to(device)
model.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
tensor_data=torch.FloatTensor(df.values).to(device)
df_encoded=model.encoder(tensor_data)
df_encoded_cpu = df_encoded.cpu().detach().numpy()

# %%
import umap.umap_ as umap
df_umapped = umap.UMAP(n_components = n_bottleneck / 2, 
                           metric = "euclidean",
                           n_neighbors = 50, 
                           min_dist = 0.0,
                           random_state = 13).fit_transform(df_encoded_cpu)
# Out:
# c:\Users\KARAN\AppData\Local\Programs\Python\Python311\Lib\site-packages\umap\umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score

# Assuming you have your review_umapped data
kmeans = KMeans(n_clusters=3, random_state=42)
cluster_labels = kmeans.fit_predict(df_umapped)

# Silhouette Score
silhouette_avg = silhouette_score(df_umapped, cluster_labels)
print(f'Silhouette Score: {silhouette_avg}')

# Davies-Bouldin Index
db_index = davies_bouldin_score(df_umapped, cluster_labels)
print(f'Davies-Bouldin Index: {db_index}')

# Calinski-Harabasz Index
ch_index = calinski_harabasz_score(df_umapped, cluster_labels)
print(f'Calinski-Harabasz Index: {ch_index}')
# Out:
# Silhouette Score: 0.6833598613739014
# Davies-Bouldin Index: 0.43446085586698163
# Calinski-Harabasz Index: 5958.792273029488
# c:\Users\KARAN\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
